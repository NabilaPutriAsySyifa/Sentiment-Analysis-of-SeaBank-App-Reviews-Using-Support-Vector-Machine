# %% [markdown]
# ## **Scraping Data Aplikasi SEA BANK SHOOPE Di Google Play Store**

# %% [markdown]
# Menggunakan tools ```google-play-scraper``` untuk mengambil data ulasan pengguna.

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# Import google-play-scraper
from google_play_scraper import reviews_all, reviews

# %%
# Mengambil ulasan pengguna aplikasi SEA BANK SHOOPE
results, _ = reviews(
    'id.co.bankbkemobile.digitalbank',
    lang='id',
    country='id',
    count=2000
)

# %%
# Preview hasil scraping
results[0]
# Out:
# {'reviewId': 'aaeaddc6-6d4b-410a-8dfd-eb87ca7ac33a',
#  'userName': 'Gondering Ctm II',
#  'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLYfejToa53C-eokgIHbUZxgNCcWpf9T0JhGTdsfDRAdjmxaQ=mo',
#  'content': 'good',
#  'score': 5,
#  'thumbsUpCount': 0,
#  'reviewCreatedVersion': '3.36.0',
#  'at': datetime.datetime(2026, 2, 14, 14, 17, 12),
#  'replyContent': None,
#  'repliedAt': None,
#  'appVersion': '3.36.0'}

# %%
# Cek jumlah data yang telah di-scrape
len(results[0])
# Out:
# 11

# %% [markdown]
# ## **Mengubah Data Scrape ke Dalam Dataframe**

# %% [markdown]
# Menggunakna library ```pandas DataFrame``` untuk mengubah data hasil scrape ke dalam format dataframe.

# %%
# Simpan data hasil scrape ke dalam dataframe
import pandas as pd
df = pd.DataFrame(results)
df
# Out:
#                                   reviewId          userName  \
# 0     aaeaddc6-6d4b-410a-8dfd-eb87ca7ac33a  Gondering Ctm II
# 1     cca25e1e-9f1b-4c76-9eb4-c32cbc6d5653     rohman rohman
# 2     a379ef06-7b42-4372-b325-5e10144094d1         dandy bae
# 3     3c7a68cd-4d66-4a2d-9b08-98aa18ecbb01     Sarip Hidayat
# 4     98d3034e-2f07-48f2-bca5-829a792cda50     Hendi Saputra
# ...                                    ...               ...
# 1995  bff35b96-cc7d-45d3-b997-1d43a5060aed   Muhamad Jaelani
# 1996  25f12483-2db2-4f49-9993-b7f317095a9f    Samuel Crisian
# 1997  68af32f9-98f6-44f7-9dfd-656a4e2eec27     Rivaldi Fatah
# 1998  0130c65c-f10d-4686-9df2-ca5f661e3782       dede naufal
# 1999  b8a96c89-166f-40ae-b8aa-be1aa28b7983      Zaki Mubarak
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...

# %% [markdown]
# ## **Manipulasi Dataframe (Hanya Ambil Kolom Ulasannya)**

# %%
# Buat salinan dataframe scrape
df_copy = df.copy()

# %%
# Cek informasi salinan
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              2000 non-null   object
#  1   userName              2000 non-null   object
#  2   userImage             2000 non-null   object
#  3   content               2000 non-null   object
#  4   score                 2000 non-null   int64
#  5   thumbsUpCount         2000 non-null   int64
#  6   reviewCreatedVersion  1817 non-null   object
#  7   at                    2000 non-null   datetime64[ns]
#  8   replyContent          284 non-null    object
#  9   repliedAt             284 non-null    datetime64[ns]
#  10  appVersion            1817 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 172.0+ KB

# %%
# Simpan hanya kolom 'reviewID' dan 'content' yang berisi ulasan pengguna
Seabank_reviews = df_copy[['content']]
Seabank_reviews
# Out:
#                                               content
# 0                                                good
# 1                                      enak dan mudah
# 2                                               bagus
# 3     mudah digunakan & cepat semua prosesnya top lah
# 4                                         sangat puas
# ...                                               ...
# 1995                                           mantap
# 1996                                     cepat proses
# 1997                                     sangat bagus
# 1998                                          muantap
# 1999                                            sulit
#
# [2000 rows x 1 columns]

# %%
# Simpan dataframe signal ke format .csv
Seabank_reviews.to_csv('seabank_reviews.csv', index=False)
